# %%
(a) Create a sample space with three or more simple events. Assign a probability to each item. Show
that the axioms of probability hold under this assignment.

My samples are A={1,2,3,4,5}
B={4,5,6,7,8}
The probability that 3 would come if we choose randomly one number from A:
Our total sample is 5 on A and 3 
so the probability of 3: P(3)=1/5
# Out:
#   Cell In [1], line 1
#     (a) Create a sample space with three or more simple events. Assign a probability to each item. Show
#         ^
# SyntaxError: invalid syntax

# %%
(b) Create a compound event that uses some of the simple events.

P(A⋂B)=1/5

# %%
(c) Compute the probability of a union and an intersection of your events.

P(A)=5/10=1/2
P(B)=5/10=1/2
P(A⋃B)=P(A)+P(B)-P(A⋂B)=(1/2)+(1/2)-(1/5)= 4/5

# %%
(d) Compute both conditional probabilities of two events. Make sure to explain what they are in
words. Apply Bayes’ theorem to verify your result.

P(A|B)=P(B|A)P(A)/P(B)=2/5

# %%
(e) Compute the probability of the complement of an event.

complement of P(A′)=1-P(A)= 1/2

# %%
(f) Simulate a simple occurrence of your sample space 10 times. Pick an event, does the simulation
give you exactly the same probability as your assignment? Explain why or why not.

By simulating A I got
1
2
2
2
4
4
5
3
1
2
No this simulation does not give me the exactly the same probability as my assignment because it act like
a gambling result.
My finding numbers are different than my actual probability

Simulation depend on the luck while probability does not depend on the luck its a actual math.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9e736b74-c673-476c-8712-ab4888ea8f3f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
